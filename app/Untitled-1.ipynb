# %%
import time
import requests
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## ASSUMPTIONS

# %%
TOTAL_SUPPLY = 1_000_000_000
KAITO_ALLOCATION = 0.0035*TOTAL_SUPPLY

SHARES = {
    "7d": 0.12 * KAITO_ALLOCATION,
    "30d": 0.16 * KAITO_ALLOCATION,
    "90d": 0.22 * KAITO_ALLOCATION,
    "180d": 0.24 * KAITO_ALLOCATION,
    "365d": 0.26 * KAITO_ALLOCATION
}

ROLE={
    'shihan':1.35,
    'senshi':1.25,
    'shugo':1.2,
    'deshi':1.1
}

GALXE_ALLOCTION = 0.035*TOTAL_SUPPLY

# %% [markdown]
# ## GALXE PART

# %%
URL = "https://graphigo.prd.galaxy.eco/query"
HEADERS = {
    "Content-Type": "application/json",
    "Origin": "https://galxe.com",
    "Referer": "https://galxe.com/",
    "User-Agent": "Mozilla/5.0"
}

def build_payload(space_id=58934, page_size=250, cursor=None):
    variables = {
        "id": space_id,
        "pageSize": page_size
    }
    if cursor:
        variables["cursorAfter"] = cursor

    query = """
    query SpaceLeaderboard($id: Int!, $pageSize: Int, $cursorAfter: String) {
      space(id: $id) {
        loyaltyPointsRanks(first: $pageSize, cursorAfter: $cursorAfter) {
          pageInfo {
            endCursor
            hasNextPage
          }
          edges {
            node {
              rank
              points
            }
          }
        }
      }
    }
    """

    return {
        "operationName": "SpaceLeaderboard",
        "variables": variables,
        "query": query
    }

# %%
total_points = 0
fetched = 0
page = 1
cursor = None
x=[]
y=[]

while fetched < 50000:
    payload = build_payload(cursor=cursor)
    res = requests.post(URL, headers=HEADERS, json=payload)
    res.raise_for_status()
    json = res.json()

    ranks = json["data"]["space"]["loyaltyPointsRanks"]["edges"]
    page_points = sum(node["node"]["points"] for node in ranks)
    total_points += page_points
    fetched += len(ranks)

    print(f"Page {page}: +{page_points:,} points ({fetched} users)")
    x.append(fetched)
    y.append(total_points)


    page_info = json["data"]["space"]["loyaltyPointsRanks"]["pageInfo"]
    if not page_info["hasNextPage"]:
        break

    cursor = page_info["endCursor"]
    page += 1
    time.sleep(0.3)

print(f"\n✅ Total Loyalty Points of Top {fetched} Users: {total_points:,}")
# Out:
# Page 1: +6,104,703 points (250 users)
# Page 2: +5,643,202 points (500 users)
# Page 3: +5,510,950 points (750 users)
# Page 4: +5,412,363 points (1000 users)
# Page 5: +5,343,402 points (1250 users)
# Page 6: +5,235,252 points (1500 users)
# Page 7: +5,153,600 points (1750 users)
# Page 8: +5,103,802 points (2000 users)
# Page 9: +5,087,500 points (2250 users)
# Page 10: +5,074,101 points (2500 users)
# Page 11: +5,024,652 points (2750 users)
# Page 12: +4,978,500 points (3000 users)
# Page 13: +4,931,752 points (3250 users)
# Page 14: +4,894,900 points (3500 users)
# Page 15: +4,851,450 points (3750 users)
# Page 16: +4,810,302 points (4000 users)
# Page 17: +4,776,853 points (4250 users)
# Page 18: +4,756,451 points (4500 users)
# Page 19: +4,737,201 points (4750 users)
# Page 20: +4,713,750 points (5000 users)
# Page 21: +4,711,700 points (5250 users)
# Page 22: +4,688,000 points (5500 users)
# Page 23: +4,680,650 points (5750 users)
# Page 24: +4,662,500 points (6000 users)
# Page 25: +4,645,351 points (6250 users)
# Page 26: +4,636,500 points (6500 users)
# Page 27: +4,613,201 points (6750 users)
# Page 28: +4,594,500 points (7000 users)
# Page 29: +4,585,900 points (7250 users)
# Page 30: +4,562,500 points (7500 users)
# Page 31: +4,562,500 points (7750 users)
# Page 32: +4,541,250 points (8000 users)
# Page 33: +4,537,500 points (8250 users)
# Page 34: +4,521,150 points (8500 users)
# Page 35: +4,498,052 points (8750 users)
# Page 36: +4,476,152 points (9000 users)
# Page 37: +4,452,750 points (9250 users)
# Page 38: +4,437,500 points (9500 users)
# Page 39: +4,423,350 points (9750 users)
# Page 40: +4,408,450 points (10000 users)
# Page 41: +4,387,500 points (10250 users)
# Page 42: +4,368,050 points (10500 users)
# Page 43: +4,354,300 points (10750 users)
# Page 44: +4,337,500 points (11000 users)
# Page 45: +4,337,500 points (11250 users)
# Page 46: +4,319,252 points (11500 users)
# Page 47: +4,312,500 points (11750 users)
# Page 48: +4,291,200 points (12000 users)
# Page 49: +4,285,650 points (12250 users)
# Page 50: +4,263,900 points (12500 users)
# Page 51: +4,258,550 points (12750 users)
# Page 52: +4,237,500 points (13000 users)
# Page 53: +4,229,100 points (13250 users)
# Page 54: +4,212,500 points (13500 users)
# Page 55: +4,204,400 points (13750 users)
# Page 56: +4,187,500 points (14000 users)
# Page 57: +4,165,850 points (14250 users)
# Page 58: +4,139,450 points (14500 users)
# Page 59: +4,112,350 points (14750 users)
# Page 60: +4,084,950 points (15000 users)
# Page 61: +4,065,450 points (15250 users)
# Page 62: +4,049,350 points (15500 users)
# Page 63: +4,028,751 points (15750 users)
# Page 64: +4,009,951 points (16000 users)
# Page 65: +4,000,000 points (16250 users)
# Page 66: +3,992,650 points (16500 users)
# Page 67: +3,982,400 points (16750 users)
# Page 68: +3,975,000 points (17000 users)
# Page 69: +3,973,401 points (17250 users)
# Page 70: +3,962,500 points (17500 users)
# Page 71: +3,951,050 points (17750 users)
# Page 72: +3,940,701 points (18000 users)
# Page 73: +3,932,400 points (18250 users)
# Page 74: +3,917,550 points (18500 users)
# Page 75: +3,909,900 points (18750 users)
# Page 76: +3,898,800 points (19000 users)
# Page 77: +3,887,500 points (19250 users)
# Page 78: +3,878,700 points (19500 users)
# Page 79: +3,870,250 points (19750 users)
# Page 80: +3,862,500 points (20000 users)
# Page 81: +3,853,351 points (20250 users)
# Page 82: +3,850,000 points (20500 users)
# Page 83: +3,840,200 points (20750 users)
# Page 84: +3,837,500 points (21000 users)
# Page 85: +3,831,400 points (21250 users)
# Page 86: +3,825,000 points (21500 users)
# Page 87: +3,824,600 points (21750 users)
# Page 88: +3,812,500 points (22000 users)
# Page 89: +3,812,500 points (22250 users)
# Page 90: +3,811,000 points (22500 users)
# Page 91: +3,800,000 points (22750 users)
# Page 92: +3,800,000 points (23000 users)
# Page 93: +3,800,000 points (23250 users)
# Page 94: +3,792,500 points (23500 users)
# Page 95: +3,787,500 points (23750 users)
# Page 96: +3,787,500 points (24000 users)
# Page 97: +3,775,150 points (24250 users)
# Page 98: +3,775,000 points (24500 users)
# Page 99: +3,773,600 points (24750 users)
# Page 100: +3,762,500 points (25000 users)
# Page 101: +3,762,500 points (25250 users)
# Page 102: +3,754,400 points (25500 users)
# Page 103: +3,750,000 points (25750 users)
# Page 104: +3,743,851 points (26000 users)
# Page 105: +3,737,500 points (26250 users)
# Page 106: +3,737,500 points (26500 users)
# Page 107: +3,725,250 points (26750 users)
# Page 108: +3,725,000 points (27000 users)
# Page 109: +3,713,051 points (27250 users)
# Page 110: +3,712,500 points (27500 users)
# Page 111: +3,700,650 points (27750 users)
# Page 112: +3,694,301 points (28000 users)
# Page 113: +3,687,500 points (28250 users)
# Page 114: +3,675,651 points (28500 users)
# Page 115: +3,664,500 points (28750 users)
# Page 116: +3,658,150 points (29000 users)
# Page 117: +3,644,350 points (29250 users)
# Page 118: +3,637,500 points (29500 users)
# Page 119: +3,628,150 points (29750 users)
# Page 120: +3,612,500 points (30000 users)
# Page 121: +3,606,850 points (30250 users)
# Page 122: +3,596,051 points (30500 users)
# Page 123: +3,587,500 points (30750 users)
# Page 124: +3,572,900 points (31000 users)
# Page 125: +3,562,500 points (31250 users)
# Page 126: +3,552,050 points (31500 users)
# Page 127: +3,545,150 points (31750 users)
# Page 128: +3,537,500 points (32000 users)
# Page 129: +3,525,400 points (32250 users)
# Page 130: +3,512,600 points (32500 users)
# Page 131: +3,504,200 points (32750 users)
# Page 132: +3,487,500 points (33000 users)
# Page 133: +3,471,850 points (33250 users)
# Page 134: +3,459,051 points (33500 users)
# Page 135: +3,439,000 points (33750 users)
# Page 136: +3,427,450 points (34000 users)
# Page 137: +3,411,651 points (34250 users)
# Page 138: +3,391,400 points (34500 users)
# Page 139: +3,381,300 points (34750 users)
# Page 140: +3,363,100 points (35000 users)
# Page 141: +3,352,101 points (35250 users)
# Page 142: +3,337,500 points (35500 users)
# Page 143: +3,321,800 points (35750 users)
# Page 144: +3,312,500 points (36000 users)
# Page 145: +3,299,200 points (36250 users)
# Page 146: +3,287,500 points (36500 users)
# Page 147: +3,286,700 points (36750 users)
# Page 148: +3,273,500 points (37000 users)
# Page 149: +3,262,500 points (37250 users)
# Page 150: +3,262,500 points (37500 users)
# Page 151: +3,262,150 points (37750 users)
# Page 152: +3,250,000 points (38000 users)
# Page 153: +3,241,550 points (38250 users)
# Page 154: +3,237,500 points (38500 users)
# Page 155: +3,231,158 points (38750 users)
# Page 156: +3,223,451 points (39000 users)
# Page 157: +3,212,500 points (39250 users)
# Page 158: +3,205,961 points (39500 users)
# Page 159: +3,196,850 points (39750 users)
# Page 160: +3,187,500 points (40000 users)
# Page 161: +3,177,712 points (40250 users)
# Page 162: +3,175,000 points (40500 users)
# Page 163: +3,175,000 points (40750 users)
# Page 164: +3,164,300 points (41000 users)
# Page 165: +3,153,855 points (41250 users)
# Page 166: +3,139,300 points (41500 users)
# Page 167: +3,133,854 points (41750 users)
# Page 168: +3,120,350 points (42000 users)
# Page 169: +3,112,500 points (42250 users)
# Page 170: +3,112,500 points (42500 users)
# Page 171: +3,100,901 points (42750 users)
# Page 172: +3,087,500 points (43000 users)
# Page 173: +3,087,500 points (43250 users)
# Page 174: +3,079,520 points (43500 users)
# Page 175: +3,062,500 points (43750 users)
# Page 176: +3,059,768 points (44000 users)
# Page 177: +3,042,450 points (44250 users)
# Page 178: +3,034,654 points (44500 users)
# Page 179: +3,017,506 points (44750 users)
# Page 180: +3,012,500 points (45000 users)
# Page 181: +2,996,917 points (45250 users)
# Page 182: +2,987,500 points (45500 users)
# Page 183: +2,986,551 points (45750 users)
# Page 184: +2,967,610 points (46000 users)
# Page 185: +2,962,500 points (46250 users)
# Page 186: +2,960,353 points (46500 users)
# Page 187: +2,942,053 points (46750 users)
# Page 188: +2,937,500 points (47000 users)
# Page 189: +2,929,802 points (47250 users)
# Page 190: +2,912,500 points (47500 users)
# Page 191: +2,912,500 points (47750 users)
# Page 192: +2,907,001 points (48000 users)
# Page 193: +2,889,050 points (48250 users)
# Page 194: +2,887,500 points (48500 users)
# Page 195: +2,887,500 points (48750 users)
# Page 196: +2,880,200 points (49000 users)
# Page 197: +2,863,200 points (49250 users)
# Page 198: +2,862,500 points (49500 users)
# Page 199: +2,862,500 points (49750 users)
# Page 200: +2,857,250 points (50000 users)
#
# ✅ Total Loyalty Points of Top 50000 Users: 763,300,134

# %%
x=np.array(x).reshape(-1, 1)
y=np.array(y)
# Polynomial features degree 2
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(x)
model = LinearRegression()
model.fit(X_poly, y)
X_plot = np.linspace(min(x), 105000, 500).reshape(-1, 1)
X_plot_poly = poly.transform(X_plot)
y_plot = model.predict(X_plot_poly)

x_pred = np.array([[100000]])
x_pred_poly = poly.transform(x_pred)
y_pred = model.predict(x_pred_poly)

# Plot data points
plt.scatter(x, y, color='blue', label='Data points')

# Plot regression curve
plt.plot(X_plot, y_plot, color='red', label='Polynomial regression')

# Mark prediction point
plt.scatter(x_pred, y_pred, color='green', s=100, label=f'Prediction at x=80,000\n(y={int(y_pred[0]):,})')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial Regression Degree 2 and Prediction')
plt.legend()
plt.grid(True)
plt.show()

# %%
Total_loyalty_points=int(y_pred)
Total_loyalty_points
# Out:
# 1113948000

# %%
Total_loyalty_points=1113948000

# %%
import requests

URL = "https://graphigo.prd.galaxy.eco/query"
HEADERS = {
    "Content-Type": "application/json",
    "Origin": "https://galxe.com",
    "Referer": "https://galxe.com/",
    "User-Agent": "Mozilla/5.0"
}

def get_loyalty_points(address, space_id=58934, season_id=None):
    variables = {
        "id": space_id,
        "address": f"EVM:{address}"
    }
    if season_id is not None:
        variables["seasonId"] = season_id

    query = """
    query SpaceLoyaltyPoints($id: Int, $address: String!, $seasonId: Int) {
      space(id: $id) {
        id
        addressLoyaltyPoints(address: $address, sprintId: $seasonId) {
          id
          points
          rank
          __typename
        }
        __typename
      }
    }
    """

    payload = {
        "operationName": "SpaceLoyaltyPoints",
        "variables": variables,
        "query": query
    }

    response = requests.post(URL, json=payload, headers=HEADERS)
    response.raise_for_status()
    return response.json()

# %%
result = get_loyalty_points("0x7ebdebe88ec46b316fdfb4e783364177c9d6bac9")
points_info = result['data']['space']['addressLoyaltyPoints']
loyalty_points=points_info['points']
loyalty_points
# Out:
# 22651

# %%
address_allocation= ((loyalty_points*ROLE['deshi'])/Total_loyalty_points)*GALXE_ALLOCTION
address_allocation
# Out:
# 779.4021803531225

# %% [markdown]
# ## KAITO PART

# %%
def fetch_data(window):
    url = "https://kaito.irys.xyz/api/community-mindshare"
    params = {"window": window}
    response = requests.get(url, params=params)
    response.raise_for_status()
    return response.json()

def calculate_allocations(username, data, window):
    share_amount = SHARES[window]
    allocation = 0
    yappers = data.get("community_mindshare", {}).get("top_1000_yappers", [])
    
    for user in yappers:
        if username == user.get("username"):
            mindshare = user.get("mindshare", 0)
            allocation = mindshare * share_amount
    return allocation

# %%
def final_allocation(username):
    timeframes = ["7d", "30d", "90d", "180d", "365d"]
    all_allocations = []
    for tf in timeframes:
        # print(f"Fetching data for {tf} ...")
        data = fetch_data(tf)
        allocs = calculate_allocations(username, data, tf)
        all_allocations.append(allocs)
    #print(all_allocations) 
    return sum(all_allocations)

# %%
username='xaitoshi_'
all_allocations=final_allocation(username)
print(f"Total Allocation: {all_allocations}")
# Out:
# Total Allocation: 33165.03762853291

# %% [markdown]
# ## TESTING

# %%
from allocation import get_address_allocation, get_kaito_allocation

# %%
get_address_allocation('0x3326f398e1abfbe6143401beb0d1847994be1c36','shihan')
# Out:
# 68.33801936894722
